# %%
from PIL import Image
from pathlib import Path
from torch.utils.data import Dataset, DataLoader
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.model_selection import train_test_split

import torchvision.transforms as transforms
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
metadata_path = Path("../data/augmented_2/metadata.csv")
augmented_dir = Path("../data/augmented_2")
df = pd.read_csv(metadata_path)
print(df.columns)
print(df.iloc[1])
# Out:
# Index(['image_path', 'label', 'caption'], dtype='object')
# image_path                                         ball_196.jpg
# label                                                Label.BALL
# caption       In the sun-drenched backyard, a joyful black a...
# Name: 1, dtype: object

# %%
def get_label(filename: str):
    return filename.split("_")[0]

def get_uuid(filename: str):
    name = Path(filename).stem
    parts = name.split("_")
    return "_".join(parts[:2])

def build_augmented_path(img_path: Path, base_dir: Path):
    img_path = Path(img_path)
    filename = img_path.name
    label = get_label(filename)
    uuid = get_uuid(filename)

    return base_dir / label / uuid / filename

get_label(df['image_path'].iloc[1])
get_uuid(df["image_path"].iloc[1])
# Out:
# 'ball_196'

# %%
captions = df["caption"].drop_duplicates().reset_index(drop=True)
print(f"Avant : {len(df)}")
print(f"Avant : {len(captions)}")
# Out:
# Avant : 800
# Avant : 800

# %% [markdown]
# TOKENIZER

# %%
vocab_size = 1000
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(captions)
actual_vocab_size = len(tokenizer.word_index) + 1
print(f"Taille du vocabulaire : {len(tokenizer.word_index)}")
print(f"Vocab size:  {actual_vocab_size}")
# Out:
# Taille du vocabulaire : 4102
# Vocab size:  4103

# %%
captions_to_sequences = tokenizer.texts_to_sequences(df["caption"])
print(df["caption"].iloc[1])
print(captions_to_sequences[1])
# Out:
# In the sun-drenched backyard, a joyful black and white dog springs into the air, its paws splayed wide as it attempts to catch the golden soccer ball perched precariously on its upturned nose. The afternoon sunlight casts a warm glow over the scene, illuminating the dog's energetic movements as it plays with its favorite ball. As the dog leaps, the ball teeters for a moment before rolling harmlessly away, inviting another joyful pursuit.
# [5, 2, 25, 301, 128, 3, 39, 32, 7, 50, 15, 831, 42, 2, 17, 10, 65, 759, 913, 6, 13, 568, 8, 111, 2, 181, 219, 20, 1, 653, 9, 10, 1, 760, 2, 70, 41, 58, 3, 23, 55, 28, 2, 21, 112, 2, 51, 76, 611, 6, 13, 370, 11, 10, 393, 20, 6, 2, 15, 195, 2, 20, 1, 45, 3, 121, 117, 535, 1, 247, 1, 232, 39, 450]

# %%
oov_id = tokenizer.word_index["<OOV>"]
count = 0
for i in  range(len(captions_to_sequences)):
    count += captions_to_sequences[i].count(oov_id)

print(count)
# Out:
# 6420

# %%
max_seq_len = max(len(seq) for seq in captions_to_sequences)
print(max_seq_len)
# Out:
# 107

# %% [markdown]
# TRANSFORMS

# %%
transforms_resnet = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# %% [markdown]
# DATASET

# %%
class CLIPDataset(Dataset):
    def __init__(self, df, base_dir: Path,
                  transform, tokenizer, max_seq_len:int):
        self.base_dir = base_dir
        

        self.img_paths = df["image_path"].tolist()
        self.labels = df["label"].tolist()
        self.captions = df["caption"].tolist()

        self.transform = transform
        self.tokenizer = tokenizer
        self.max_length = max_seq_len
        
        self.classes = sorted(set(self.labels))
        self.class_to_idx = {cls: i for i, cls in enumerate(self.classes)}

    def __getitem__(self, idx):
        img_path = Path(build_augmented_path(self.img_paths[idx], self.base_dir))
        img = Image.open(img_path).convert("RGB")
        img = self.transform(img)

        caption = self.captions[idx]

        seq = self.tokenizer.texts_to_sequences([caption])  
        padded = pad_sequences(
            seq,
            maxlen=self.max_length,
            padding="post",
            truncating="post"
        )

        padded = torch.tensor(padded[0], dtype=torch.long)   # (max_seq_len,)

        label = torch.tensor(self.class_to_idx[self.labels[idx]])
        return {
            "caption": caption, 
            "index": idx,
            "image": img,
            "input_ids": padded,
            "label": label
        }

    def __len__(self):
        return len(self.img_paths)

# %%
# df["caption_to_seq"] = tokenizer.texts_to_sequences(df["caption"].tolist())

# padded = pad_sequences(
#     df["caption_to_seq"],
#     maxlen=max_seq_len,
#     padding='post',
#     truncating='post'
# )

# df["seq_padded"] = list(padded)

# print(df["caption"].iloc[1])
# print(df["caption_to_seq"].iloc[1])
# print(df["seq_padded"].iloc[1])

# %%
df_train, df_temp = train_test_split(df, test_size=0.3, random_state=11)
df_test, df_val = train_test_split(df_temp, test_size=0.15, random_state=11)

# %%
print(df_train["label"].value_counts(normalize=True) * 100)
print(df_test["label"].value_counts(normalize=True) * 100)
print(df_val["label"].value_counts(normalize=True) * 100)
# Out:
# label
# Label.BALL     25.357143
# Label.WATER    25.178571
# Label.DOG      25.178571
# Label.BIKE     24.285714
# Name: proportion, dtype: float64
# label
# Label.BIKE     26.960784
# Label.DOG      25.490196
# Label.WATER    25.000000
# Label.BALL     22.549020
# Name: proportion, dtype: float64
# label
# Label.BALL     33.333333
# Label.BIKE     25.000000
# Label.WATER    22.222222
# Label.DOG      19.444444
# Name: proportion, dtype: float64

# %%
train_dataset = CLIPDataset(df_train, augmented_dir, transforms_resnet, tokenizer,max_seq_len)
test_dataset = CLIPDataset(df_test, augmented_dir, transforms_resnet, tokenizer, max_seq_len)
val_dataset = CLIPDataset(df_val, augmented_dir,  transforms_resnet, tokenizer, max_seq_len)

# %%
print(len(val_dataset))
# Out:
# 36

# %%
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, drop_last=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True, drop_last=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=True, drop_last=True)

# %%
for batch in val_loader:
    print(batch)
# Out:
# {'caption': ['A playful black and white dog bounds through the lush green yard, its tail wagging excitedly as it carries a bright blue ball in its mouth. The sun casts dappled shadows on the grass, and a few palm trees sway gently in the breeze behind the dog. In the background, a colorful beach umbrella stands near a small house with a thatched roof, adding to the tropical ambiance of the scene.', 'A fluffy tan dog, its curly coat fluffed up against the cold, bounds through the snow-covered backyard with joyful abandon, a stick clutched tightly in its jaws as it playfully leaps over a mound of powder. The crisp winter air carries the scent of fresh-cut grass and wood smoke from a nearby fire pit, adding to the cozy atmosphere of the scene. As the dog runs, its tail wags furiously, leaving behind a trail of disturbed snow in its wake.', "Outside a primary school, a group of children in their uniforms stand eagerly beside a small playground, chatting excitedly with each other as they wait for recess to begin. Amidst them, a fluffy golden retriever wagging its tail joyfully plays catch with one of the kids, adding to the lively atmosphere of the morning scene. The dog's owner, a smiling teacher, watches over the children from a nearby bench, making sure everyone stays safe and happy.", "A sunny afternoon in the backyard, with the warm grass beneath the paws of a playful dachshund named Max. He's caught sight of his beloved tennis ball rolling across the lawn and can't resist giving chase, his little legs moving as fast as they can to get back to the game. With a joyful yelp, he leaps into the air, snatching up the ball in mid-air and proudly carrying it back to his owner for praise and affection.", "A girl clad in a reflective jacket pedals her bike along a dimly lit street, the wheels humming softly on the pavement as she makes her way home from a late-night ride with friends. The streetlights cast long shadows behind the parked cars and buildings, creating an eerie yet peaceful atmosphere. A faint glow emanates from the nearby houses, illuminating the girl's determined face as she navigates through the quiet evening streets.", 'A rugged dirt path winds through a sun-drenched landscape, flanked by tall trees and rocky outcroppings. A man in blue jeans and a worn jacket stands atop his bike, the engine revving as he prepares to launch himself over a small jump. The scene is one of high-octane freedom, with the thrill of off-road adventure palpable in every detail.', 'A young girl, dressed in a crisp white coat, stands playfully in the center of a serene fountain, surrounded by gently splashing water. The sun casts a warm glow on the scene, causing the droplets to sparkle like tiny diamonds. Meanwhile, her friend, a boy with an infectious grin, looks on from the background, clearly enjoying the impromptu water feature that has brought so much joy to their afternoon.', "The warm sunlight casts a gentle glow over the vibrant green lawn, where a blond boy's squeals of delight echo through the air as he effortlessly glides down the inflatable slide into the sparkling blue water of the backyard pool. The sound of laughter and splashing ripples out across the yard, accompanied by the soft chirping of birds singing their morning songs from the nearby trees. In the distance, a colorful beach umbrella stands tall, adding a pop of color to the serene scene.", "In the midst of a lively game, two playful black dogs are engrossed in a thrilling tug-of-war over a small red rubber ball, their eager faces fixed on the coveted prize as they try to wrestle it away from each other. The grassy field around them is dotted with scattered leaves and twigs, a testament to the energetic exchange that's unfolding. The atmosphere is one of joyful chaos, with both dogs completely absorbed in the game, oblivious to everything else.", "A playful black dog, its fur fluffed up from the ocean breeze, runs swiftly across the sandy beach, its tail wagging excitedl ...
#           [-1.4500, -1.0733, -0.8335,  ...,  0.6563,  0.7419,  0.7762],
#           [-1.3130, -1.4329, -1.3473,  ...,  0.3823,  0.6906,  0.6734],
#           ...,
#           [-0.0116, -0.0287, -0.3883,  ..., -1.2274, -1.5699, -1.4672],
#           [-0.4739, -0.2856, -0.7137,  ..., -1.2274, -1.4158, -1.5699],
#           [-0.9192, -1.0048, -1.2788,  ..., -1.4329, -1.5357, -1.4843]],
#
#          [[ 1.0630,  1.0805,  0.9055,  ...,  0.4328,  0.5378,  0.1877],
#           [-1.2304, -0.8452, -0.6352,  ...,  0.7829,  0.7829,  0.7829],
#           [-1.1779, -1.2829, -1.1604,  ...,  0.3978,  0.8179,  0.8529],
#           ...,
#           [ 0.4678,  0.5028,  0.3102,  ..., -0.1099, -0.4076, -0.3200],
#           [ 0.0826,  0.3452,  0.0126,  ..., -0.0924, -0.3550, -0.6001],
#           [-0.2850, -0.2850, -0.4951,  ..., -0.2675, -0.5301, -0.5651]],
#
#          [[-0.1835,  0.0605, -0.0267,  ..., -0.6890, -0.3055, -0.5321],
#           [-1.6127, -1.4210, -1.4384,  ..., -0.3055, -0.0790,  0.0256],
#           [-1.5953, -1.7870, -1.8044,  ..., -0.6367, -0.0441,  0.0779],
#           ...,
#           [ 0.1825,  0.0953, -0.2707,  ..., -0.8633, -1.1770, -1.0898],
#           [-0.2707, -0.1138, -0.6018,  ..., -0.8807, -1.1073, -1.2816],
#           [-0.7064, -0.8110, -1.1596,  ..., -1.0898, -1.2641, -1.2467]]],
#
#
#         [[[ 0.9132,  0.8447,  0.7933,  ..., -1.6727, -1.6898, -1.6898],
#           [ 1.1700,  1.1015,  1.0331,  ..., -1.6555, -1.6727, -1.6727],
#           [ 1.2728,  1.2385,  1.2385,  ..., -1.6384, -1.6555, -1.6555],
#           ...,
#           [ 0.4166,  0.5022,  0.6049,  ...,  0.8276,  0.9303,  0.9303],
#           [ 0.5536,  0.6049,  0.7248,  ...,  0.8447,  0.9132,  0.9303],
#           [ 0.7248,  0.8447,  0.7419,  ...,  0.8447,  0.8789,  0.9132]],
#
#          [[ 1.2206,  1.1506,  1.0980,  ..., -1.2654, -1.2654, -1.2654],
#           [ 1.5007,  1.4307,  1.3606,  ..., -1.2479, -1.2479, -1.2479],
#           [ 1.5882,  1.5532,  1.5707,  ..., -1.2304, -1.2304, -1.2304],
#           ...,
#           [ 0.7479,  0.8354,  0.9405,  ...,  1.1681,  1.2381,  1.2206],
#           [ 0.8880,  0.9405,  1.0630,  ...,  1.2031,  1.2206,  1.2206],
#           [ 1.0630,  1.1856,  1.0805,  ...,  1.2031,  1.2031,  1.2031]],
#
#          [[ 1.5420,  1.4897,  1.4374,  ..., -0.4275, -0.4798, -0.5147],
#           [ 1.7685,  1.6988,  1.6291,  ..., -0.4101, -0.4624, -0.4624],
#           [ 1.8208,  1.7860,  1.7860,  ..., -0.3753, -0.4101, -0.4275],
#           ...,
#           [ 1.0714,  1.1585,  1.2631,  ...,  1.4025,  1.4722,  1.4897],
#           [ 1.1934,  1.2282,  1.3502,  ...,  1.4200,  1.4722,  1.4722],
#           [ 1.3502,  1.4722,  1.3677,  ...,  1.4200,  1.4200,  1.4200]]],
#
#
#         [[[ 2.1633,  2.1119,  2.0605,  ..., -1.0390, -1.4843, -1.3130],
#           [ 2.1975,  2.1633,  2.1290,  ..., -1.3815, -1.1589, -1.5185],
#           [ 2.1975,  2.2147,  2.1804,  ..., -1.4158, -1.2274, -1.3815],
#           ...,
#           [ 0.6734,  0.3138,  0.3823,  ...,  0.4851,  0.3309,  0.0398],
#           [ 0.8447,  0.4508,  0.4679,  ...,  0.6563,  0.2796, -0.0116],
#           [ 0.5536,  0.2453,  0.2624,  ...,  0.5193,  0.3138,  0.2111]],
#
#          [[ 2.3585,  2.3060,  2.2710,  ..., -0.7227, -1.1779, -1.0378],
#           [ 2.3761,  2.3585,  2.3235,  ..., -1.0903, -0.8452, -1.2129],
#           [ 2.3761,  2.3936,  2.3761,  ..., -1.1604, -0.9503, -1.0903],
#           ...,
#           [ 0.8704,  0.5203,  0.5728,  ...,  0.8354,  0.7479,  0.4678],
#           [ 0.9755,  0.5903,  0.6429,  ...,  0.9405,  0.7129,  0.4853],
#           [ 0.6429,  0.3452,  0.4153,  ...,  0.7479,  0.7654,  0.7479]],
#
#          [[ 2.6226,  2.5180,  2.4657,  ..., -0.6367, -1.0201, -0.8458],
#           [ 2.6051,  2.5703,  2.5180,  ..., -0.9853, -0.6890, -1.0376],
#           [ 2.5703,  2.5703,  2.5354,  ..., -1.0201, -0.8110, -0.9504],
#           ...,
#           [ 0.8099,  0.4439,  0.5136,  ..., -0.0964, -0.2707, -0.5844],
#           [ 0.9668,  0.5659,  0.6008,  ..., -0.0092, -0.2881, -0.5495],
#           [ 0.6531,  0.3742,  0.4091,  ..., -0.2010, -0.2532, -0.2707]]],
#
#
#         ...,
#
#
#         [[[-1.6898, -1.7069, -1.7240,  ..., -1.8097, -1.7754, -1.8782],
#           [-1.6384, -1.6555, -1.7412,  ..., -1.6042, -1.3815, -1.8782],
#           [-1.8268, -1.7412, -1.7069,  ..., -1.8610, -1.5870, -1.8439],
#           ...,
#           [-0.1143, -0.0801, -0.0116,  ..., -0.0972,  0.1939,  0.0227],
#           [-0.2171, -0.2513, -0.1828,  ..., -0.0972,  0.1426, -0.0801],
#           [ 0.0912, -0.0972,  0.1083,  ..., -0.1828, -0.0287, -0.0458]],
#
#          [[-1.5805, -1.5980, -1.6155,  ..., -1.4930, -1.5630, -1.7206],
#           [-1.5280, -1.5455, -1.6331,  ..., -1.2654, -1.1779, -1.7206],
#           [-1.7206, -1.6331, -1.5980,  ..., -1.5630, -1.3880, -1.6856],
#           ...,
#           [ 0.1001,  0.0826,  0.1527,  ..., -0.1450,  0.2052,  0.0476],
#           [-0.0049, -0.0924, -0.0749,  ..., -0.1975,  0.1176, -0.0749],
#           [ 0.3102,  0.0651,  0.1877,  ..., -0.2850, -0.0749, -0.0749]],
#
#          [[-1.3164, -1.3339, -1.3513,  ..., -1.3513, -1.3687, -1.5081],
#           [-1.2641, -1.2816, -1.3687,  ..., -1.1247, -0.9853, -1.5081],
#           [-1.4559, -1.3687, -1.3339,  ..., -1.4210, -1.1944, -1.4733],
#           ...,
#           [ 0.1999,  0.1999,  0.2696,  ...,  0.1302,  0.4788,  0.3219],
#           [ 0.0953,  0.0256,  0.0779,  ...,  0.0779,  0.3916,  0.1825],
#           [ 0.4265,  0.1999,  0.3742,  ..., -0.0092,  0.1999,  0.1999]]],
#
#
#         [[[-1.6898, -1.8097, -1.6384,  ..., -0.3712, -0.0972, -0.0801],
#           [-1.6555, -1.5185, -1.7240,  ..., -0.0458,  0.1597,  0.2624],
#           [-1.3302, -1.1932, -1.6384,  ..., -0.3369,  0.2796, -0.1657],
#           ...,
#           [ 0.3823,  0.3994,  0.3994,  ...,  0.4508,  0.3823,  0.3652],
#           [ 0.4508,  0.4337,  0.4337,  ...,  0.4166,  0.3823,  0.3481],
#           [ 0.3652,  0.3994,  0.4508,  ...,  0.4337,  0.3994,  0.3481]],
#
#          [[-1.7031, -1.8081, -1.6155,  ..., -0.3550, -0.0224, -0.0049],
#           [-1.6681, -1.5280, -1.7031,  ..., -0.0224,  0.2052,  0.3452],
#           [-1.3179, -1.1779, -1.6155,  ..., -0.3375,  0.2927, -0.1450],
#           ...,
#           [ 0.0476,  0.0651,  0.0651,  ...,  0.3277,  0.2752,  0.2927],
#           [ 0.1176,  0.1001,  0.1001,  ...,  0.2927,  0.2927,  0.2752],
#           [ 0.0301,  0.0651,  0.1176,  ...,  0.3102,  0.3102,  0.2752]],
#
#          [[-1.4733, -1.5779, -1.4036,  ..., -0.3753, -0.0790, -0.0615],
#           [-1.4384, -1.2990, -1.4907,  ..., -0.0441,  0.2173,  0.3568],
#           [-1.1073, -0.9678, -1.3861,  ..., -0.3404,  0.3742, -0.0441],
#           ...,
#           [-0.2358, -0.2184, -0.2184,  ..., -0.0790, -0.1661, -0.1835],
#           [-0.1661, -0.1835, -0.1835,  ..., -0.1138, -0.1835, -0.2184],
#           [-0.2532, -0.2358, -0.1835,  ..., -0.0964, -0.1661, -0.2358]]],
#
#
#         [[[-0.3369, -0.5082, -0.3712,  ..., -1.5870, -1.5185, -1.5185],
#           [ 0.0227, -0.5253, -1.1760,  ..., -1.6213, -1.5528, -1.5357],
#           [-0.8335, -0.8335, -0.9705,  ..., -1.6555, -1.5870, -1.5699],
#           ...,
#           [-1.8097, -1.6213, -1.7925,  ..., -1.2274, -1.3130, -1.4158],
#           [-1.6042, -1.6727, -1.8782,  ..., -1.5870, -1.7240, -1.6898],
#           [-1.7240, -1.6042, -1.4500,  ..., -2.0494, -1.9980, -1.7754]],
#
#          [[ 0.0651, -0.1099, -0.0049,  ..., -1.4755, -1.4055, -1.4055],
#           [ 0.3978, -0.1800, -0.8627,  ..., -1.5105, -1.4405, -1.4230],
#           [-0.5476, -0.5476, -0.7052,  ..., -1.5455, -1.4755, -1.4580],
#           ...,
#           [-1.6506, -1.4405, -1.6155,  ..., -1.0903, -1.1954, -1.2829],
#           [-1.4580, -1.5280, -1.7381,  ..., -1.4580, -1.5980, -1.5630],
#           [-1.5805, -1.4580, -1.3004,  ..., -1.9482, -1.8782, -1.6506]],
#
#          [[-1.3687, -1.4733, -1.2816,  ..., -1.5081, -1.5081, -1.5256],
#           [-0.8633, -1.3339, -1.6127,  ..., -1.5430, -1.5256, -1.5256],
#           [-1.4384, -1.3861, -1.4384,  ..., -1.5779, -1.5604, -1.5430],
#           ...,
#           [-1.6824, -1.5430, -1.6999,  ..., -1.1247, -1.2119, -1.2641],
#           [-1.5430, -1.6127, -1.7522,  ..., -1.4036, -1.5430, -1.5430],
#           [-1.6824, -1.5604, -1.4036,  ..., -1.8044, -1.7870, -1.6476]]]]), 'input_ids': tensor([[  3,  40,  32,  ...,   0,   0,   0],
#         [  3, 300, 987,  ...,   0,   0,   0],
#         [795,   3,   1,  ...,   0,   0,   0],
#         ...,
#         [  2,   1, 197,  ...,   0,   0,   0],
#         [  3,   1,  10,  ...,   0,   0,   0],
#         [  2, 161, 180,  ...,   0,   0,   0]]), 'label': tensor([0, 2, 2, 0, 1, 1, 3, 3, 0, 2, 2, 1, 3, 2, 3, 1])}
# {'caption': ['A young boy, his eyes fixed on the ball in his paws, charges out of the calm morning surf as he playfully runs alongside his energetic black and brown dog. The warm sunlight catches the waves as they lap gently at the shore, and the sound of seagulls fills the air. In a split second, the dog will be off to retrieve the ball, sending them both tumbling onto the sandy beach in a joyful heap.', "In this playful scene, two energetic dogs, one black and the other also sporting a sleek black coat, can be seen running in perfect synchrony alongside each other. As they stretch their legs to their full potential, they're completely absorbed in their game of friendly competition, chasing after a small, white ball that bounces and rolls across the lush green grass. The sun shines down on them, casting a warm glow over the entire scene as the dogs continue their joyful pursuit of the elusive ball.", 'A young boy, laughing as he tries to shake off the soaking wet clothes, stands in the downpour with his arms raised in surrender. Rainwater pours off the brim of his cap and drips from the tip of his nose. The sound of raindrops hitting the pavement creates a soothing melody in the background.', "A playful brown dog, its fur fluffed up with excitement, bounds through the yard in hot pursuit of a well-worn tennis ball that's been tattered by repeated tosses and catches. The sun casts a warm glow over the scene as the dog weaves between tall blades of grass, its tail wagging wildly as it gains on its quarry. In the background, a few colorful flowers bloom amidst the lush greenery, adding a pop of vibrancy to the otherwise energetic pursuit.", "A woman, likely a mother, is playfully chasing after her young son as he runs around in a park on a sunny day. She's holding onto a white tennis ball tightly, her arm extended behind her as she tries to catch up to her energetic child. The boy's laughter echoes through the air as he darted away from his mom, ball-free once again.", 'A young bike rider has taken to the air above a makeshift ramp in a skatepark, their boarder-style bicycle soaring through the mid-air as they perform a daring trick. The ramp stretches out before them, a long, curved concrete slope that provides the perfect launchpad for this aerial stunt. A few onlookers stand nearby, cheering and snapping photos of the impressive feat.', "A sleek black agility dog, its fur glistening with sweat, navigates a challenging obstacle course with ease, expertly weaving in and out of towering poles set up by its enthusiastic owner. The dog's paws barely touch the ground as it springs from one pole to the next, its tail wagging triumphantly in the air. The scene is bathed in the warm glow of late afternoon sunlight, casting long shadows across the grassy terrain.", "A young child, dressed in a colorful swimsuit, giggles with glee as they splash and play in a backyard pool on a warm summer day. Water droplets sparkle in the sunlight as the baby's small hands send waves crashing against the pool's edge. The atmosphere is carefree and joyful, filled with the sounds of splashing water and happy laughter.", "A playful scene unfolds in a sun-dappled park on a warm afternoon. A woman, dressed in a black skirt and blue shirt with a beige vest, stands with her back to the camera, holding a ball in mid-air as if about to toss it for her energetic canine companion, who is jumping up excitedly, its paws waving wildly as it strains to catch the ball. The woman's laughter carries through the air as she prepares for another playful throw.", 'A woman in a bold outfit pedals her sleek bicycle down a bustling city street, drawing curious glances from passersby. On her back, she wears a pair of black, intricately designed wings attached to a gleaming metal frame, which seems almost too heavy for its delicate attachment points. Nearby pedestrians exchange knowing smiles and nods as they continue on their own daily routines.', "A playful Corgi bursts out o ...
#           [-0.0458, -0.0629, -0.0629,  ..., -0.6109, -0.5938, -0.5938],
#           [-0.0116, -0.0458, -0.1657,  ..., -0.4911, -0.5082, -0.5424],
#           ...,
#           [ 0.0569, -0.0629,  0.0912,  ..., -0.0287,  0.0056,  0.0056],
#           [ 0.0227, -0.0972,  0.0227,  ...,  0.0056,  0.0227,  0.0398],
#           [ 0.1426,  0.1768,  0.1768,  ...,  0.2282,  0.2111,  0.2967]],
#
#          [[ 0.4328,  0.3978,  0.3102,  ..., -0.2500, -0.2150, -0.1625],
#           [ 0.3452,  0.3277,  0.3277,  ..., -0.2500, -0.1975, -0.1625],
#           [ 0.3803,  0.3452,  0.2227,  ..., -0.1099, -0.1099, -0.1275],
#           ...,
#           [ 0.0476, -0.0749,  0.0826,  ..., -0.0224,  0.0651,  0.0651],
#           [ 0.0476, -0.0749,  0.0651,  ...,  0.0476,  0.1001,  0.1352],
#           [ 0.2227,  0.2402,  0.2227,  ...,  0.2927,  0.3102,  0.3978]],
#
#          [[ 0.7751,  0.7402,  0.6531,  ..., -0.0267, -0.0267,  0.0256],
#           [ 0.6879,  0.6705,  0.6705,  ..., -0.0092,  0.0431,  0.0779],
#           [ 0.7228,  0.6879,  0.5659,  ...,  0.1999,  0.1825,  0.1651],
#           ...,
#           [ 0.2348,  0.1302,  0.2871,  ...,  0.1825,  0.3045,  0.3045],
#           [ 0.2696,  0.1476,  0.2871,  ...,  0.2696,  0.3568,  0.4091],
#           [ 0.4614,  0.4962,  0.4788,  ...,  0.5485,  0.5834,  0.6705]]],
#
#
#         [[[-1.3644, -1.7412, -1.7754,  ..., -0.8335,  0.2624,  1.1872],
#           [-1.3130, -1.6042, -1.6042,  ..., -0.9363,  0.2453,  1.2728],
#           [-1.3987, -1.5357, -1.5699,  ..., -0.8335,  0.2453,  1.2385],
#           ...,
#           [ 0.1083,  0.0741, -0.1999,  ...,  2.0948,  1.9578,  1.3242],
#           [-0.1657, -0.3369, -0.5253,  ...,  1.9920,  1.9749,  1.8208],
#           [ 0.9303,  0.8961,  0.8104,  ...,  1.7865,  2.0263,  2.0092]],
#
#          [[-0.9153, -1.3004, -1.3354,  ..., -0.5301,  0.5203,  1.3957],
#           [-0.8627, -1.1604, -1.1604,  ..., -0.6877,  0.4678,  1.4307],
#           [-0.9503, -1.0903, -1.1253,  ..., -0.6527,  0.3803,  1.3256],
#           ...,
#           [-0.1800, -0.2150, -0.5126,  ...,  2.2010,  2.0259,  1.3256],
#           [-0.3025, -0.4951, -0.7227,  ...,  1.9909,  1.9734,  1.7983],
#           [ 0.8880,  0.8179,  0.6779,  ...,  1.7458,  1.9909,  1.9734]],
#
#          [[-0.8807, -1.2641, -1.2990,  ..., -0.5147,  0.6182,  1.5594],
#           [-0.8284, -1.1247, -1.1247,  ..., -0.6367,  0.5659,  1.6291],
#           [-0.9156, -1.0550, -1.0898,  ..., -0.5844,  0.5136,  1.5420],
#           ...,
#           [-0.3753, -0.4101, -0.6715,  ...,  2.3611,  2.1868,  1.5245],
#           [-0.2707, -0.4275, -0.6018,  ...,  2.2217,  2.1868,  2.0474],
#           [ 1.0365,  1.0539,  0.9842,  ...,  1.9951,  2.2391,  2.2217]]],
#
#
#         [[[-0.2513, -0.1657, -0.1828,  ..., -0.7308, -0.6281, -0.5424],
#           [-0.2684, -0.1486, -0.1143,  ...,  0.2282,  0.2453,  0.2624],
#           [-0.2513, -0.1486, -0.0972,  ...,  0.0741,  0.0741,  0.0569],
#           ...,
#           [-0.3198, -0.2856, -0.2684,  ..., -0.5767, -0.4397, -0.3883],
#           [-0.3369, -0.3027, -0.2684,  ..., -0.5596, -0.4226, -0.3027],
#           [-0.3369, -0.3027, -0.2684,  ..., -0.6452, -0.5767, -0.4568]],
#
#          [[ 0.5203,  0.6078,  0.5903,  ...,  0.0826,  0.1877,  0.2577],
#           [ 0.5028,  0.6254,  0.6604,  ...,  0.9930,  1.0105,  1.0280],
#           [ 0.5203,  0.6254,  0.6779,  ...,  0.7829,  0.7654,  0.7479],
#           ...,
#           [ 0.5028,  0.5378,  0.5553,  ...,  0.1702,  0.3102,  0.3627],
#           [ 0.4678,  0.5028,  0.5378,  ...,  0.1877,  0.3277,  0.4503],
#           [ 0.4678,  0.5028,  0.5378,  ...,  0.1001,  0.1702,  0.2927]],
#
#          [[ 1.1934,  1.2805,  1.2631,  ...,  0.6531,  0.7576,  0.8274],
#           [ 1.1759,  1.2980,  1.3328,  ...,  1.5245,  1.5594,  1.5594],
#           [ 1.1934,  1.2980,  1.3502,  ...,  1.2282,  1.2282,  1.2282],
#           ...,
#           [ 1.1759,  1.2108,  1.2282,  ...,  0.9842,  1.1237,  1.1759],
#           [ 1.1934,  1.2108,  1.2457,  ...,  1.0017,  1.1411,  1.2631],
#           [ 1.1934,  1.2282,  1.2631,  ...,  0.9145,  0.9842,  1.1062]]],
#
#
#         ...,
#
#
#         [[[-1.8268, -1.8439, -1.8268,  ..., -2.1179, -2.1179, -2.1008],
#           [-1.9124, -1.8782, -1.8610,  ..., -2.1179, -2.1179, -2.1008],
#           [-2.0152, -1.9638, -1.9638,  ..., -2.1179, -2.1179, -2.1008],
#           ...,
#           [ 0.6049,  0.6906,  0.8618,  ...,  1.5982,  1.5297,  1.5297],
#           [ 0.3309,  0.3138,  0.3994,  ...,  1.5982,  1.5468,  1.5297],
#           [ 0.5193,  0.5536,  0.6906,  ...,  1.5810,  1.5468,  1.4612]],
#
#          [[-0.4251, -0.4426, -0.4251,  ..., -0.8277, -0.8803, -0.8978],
#           [-0.4951, -0.4601, -0.4426,  ..., -0.8277, -0.8803, -0.8978],
#           [-0.5651, -0.4951, -0.5126,  ..., -0.8452, -0.8803, -0.8978],
#           ...,
#           [-0.6176, -0.5301, -0.3901,  ...,  0.2577,  0.2227,  0.2402],
#           [-0.8102, -0.8452, -0.7927,  ...,  0.2577,  0.2052,  0.2052],
#           [-0.6352, -0.6001, -0.5126,  ...,  0.2402,  0.1877,  0.1001]],
#
#          [[-0.7238, -0.7413, -0.7238,  ..., -1.0724, -1.1073, -1.1247],
#           [-0.7936, -0.7587, -0.7413,  ..., -1.0724, -1.1073, -1.1247],
#           [-0.8807, -0.8284, -0.8284,  ..., -1.0898, -1.1073, -1.1247],
#           ...,
#           [-0.7587, -0.6890, -0.5670,  ...,  0.0082, -0.0441, -0.0267],
#           [-0.9504, -1.0027, -0.9330,  ...,  0.0082, -0.0441, -0.0615],
#           [-0.7936, -0.7587, -0.6715,  ..., -0.0092, -0.0441, -0.1487]]],
#
#
#         [[[-1.7583, -1.7583, -1.7754,  ...,  1.1358,  0.7591,  0.0056],
#           [-1.8439, -1.8782, -1.9124,  ...,  1.1700,  0.7933,  0.0569],
#           [-1.9638, -1.9467, -1.9295,  ...,  1.1872,  0.8104,  0.0912],
#           ...,
#           [ 1.6495,  1.6495,  1.6324,  ...,  0.9132,  0.8276,  0.7933],
#           [ 1.7694,  1.7694,  1.7865,  ...,  0.8447,  0.8276,  0.8789],
#           [ 1.7009,  1.7180,  1.7352,  ...,  0.7762,  0.8276,  0.7591]],
#
#          [[-1.5105, -1.5105, -1.5280,  ...,  0.6604,  0.4153, -0.2500],
#           [-1.5980, -1.6331, -1.6681,  ...,  0.6954,  0.4503, -0.2150],
#           [-1.7206, -1.7031, -1.6856,  ...,  0.6779,  0.4678, -0.1975],
#           ...,
#           [ 1.4482,  1.4482,  1.4482,  ...,  0.6954,  0.5728,  0.5553],
#           [ 1.6758,  1.6758,  1.6933,  ...,  0.5903,  0.5728,  0.5903],
#           [ 1.6583,  1.6758,  1.6933,  ...,  0.5028,  0.5553,  0.4678]],
#
#          [[-1.6476, -1.6476, -1.6476,  ..., -0.0441, -0.2707, -0.8458],
#           [-1.6824, -1.7347, -1.7696,  ..., -0.0092, -0.2184, -0.7936],
#           [-1.7696, -1.7696, -1.7522,  ...,  0.0082, -0.2010, -0.7761],
#           ...,
#           [ 1.4374,  1.4374,  1.4200,  ...,  0.4962,  0.3742,  0.3219],
#           [ 1.5594,  1.5594,  1.5942,  ...,  0.3916,  0.3742,  0.4265],
#           [ 1.4897,  1.5071,  1.5420,  ...,  0.3045,  0.3568,  0.2871]]],
#
#
#         [[[-0.7822, -0.7993, -0.8164,  ..., -1.5699, -1.5870, -1.6213],
#           [-0.8849, -0.8849, -0.9020,  ..., -1.5870, -1.5870, -1.6213],
#           [-0.9877, -0.9363, -0.8678,  ..., -1.5528, -1.6213, -1.6555],
#           ...,
#           [-0.5253, -0.5082, -0.4568,  ..., -0.7308, -0.0801,  0.2282],
#           [-0.2684, -0.2513, -0.2171,  ..., -0.4568,  0.3138,  0.4166],
#           [-0.0458, -0.0629, -0.0287,  ..., -0.4911,  0.0056,  0.0912]],
#
#          [[-0.9503, -0.9678, -0.9853,  ..., -1.4930, -1.4755, -1.5105],
#           [-1.0553, -1.0553, -1.0728,  ..., -1.5105, -1.4755, -1.5105],
#           [-1.1604, -1.1078, -1.0378,  ..., -1.4755, -1.5105, -1.5455],
#           ...,
#           [-0.9678, -0.9678, -0.9153,  ..., -0.9678, -0.3901, -0.0749],
#           [-0.7052, -0.6877, -0.6527,  ..., -0.6877,  0.0651,  0.1702],
#           [-0.4601, -0.4776, -0.4601,  ..., -0.7402, -0.2500, -0.1450]],
#
#          [[-0.9504, -0.9678, -0.9853,  ..., -1.3339, -1.3513, -1.3861],
#           [-1.0550, -1.0550, -1.0724,  ..., -1.3513, -1.3513, -1.3687],
#           [-1.1596, -1.1073, -1.0376,  ..., -1.3164, -1.3687, -1.4036],
#           ...,
#           [-1.0898, -1.0898, -1.0550,  ..., -0.6367, -0.1661,  0.0779],
#           [-0.8981, -0.8807, -0.8458,  ..., -0.3753,  0.1302,  0.1476],
#           [-0.7064, -0.7238, -0.7238,  ..., -0.4275, -0.2184, -0.2532]]]]), 'input_ids': tensor([[  3,  38,  66,  ...,   0,   0,   0],
#         [  5,  69,  40,  ...,   0,   0,   0],
#         [  3,  38,  66,  ...,   0,   0,   0],
#         ...,
#         [  2, 318, 215,  ...,   0,   0,   0],
#         [  3, 185,   4,  ...,   0,   0,   0],
#         [  3, 272, 162,  ...,   0,   0,   0]]), 'label': tensor([0, 0, 3, 0, 0, 1, 2, 3, 0, 1, 2, 0, 3, 0, 1, 1])}

# %%
import torchvision.models as models


class VisionEncoder(nn.Module):
    def __init__(self, embed_dim=128):
        super().__init__()
        base_model = models.resnet18(weights=models.ResNet18_Weights.IMAGENET1K_V1)

        self.backbone = nn.Sequential(
                     base_model.conv1, base_model.bn1, base_model.relu, base_model.maxpool, 
                     base_model.layer1, base_model.layer2, base_model.layer3, base_model.layer4, base_model.avgpool,
                 )
        
        # Projection linéaire vers l'espace d'embedding
        self.proj = nn.Linear(base_model.fc.in_features, embed_dim)


    def forward(self, x):
        x = self.backbone(x)         # [B, 512, 1, 1]
        x = x.flatten(1)             # [B, 512]
        x = self.proj(x)             # [B, embed_dim]
        return x

# %%
class PositionalEmbedding(nn.Module):
    def __init__(self, sequence_length: int, vocab_size:int, embed_dim:int):
        super().__init__()
        self.token_embeddings = nn.Embedding(vocab_size, embed_dim)
        self.position_embeddings = nn.Embedding(sequence_length, embed_dim)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        batch_size, seq_len = x.size()
        positions = torch.arange(seq_len, device=x.device).unsqueeze(0).expand(batch_size, seq_len)
        return self.token_embeddings(x) + self.position_embeddings(positions)


class TransformerBlock(nn.Module):
    def __init__(self, embed_dim: int, num_heads: int, ff_dim: int, dropout_rate: float = 0.1) -> None:
        super().__init__()
        self.att = nn.MultiheadAttention(embed_dim, num_heads, dropout=dropout_rate, batch_first=True)

        self.ffn = nn.Sequential(
            nn.Linear(embed_dim, ff_dim),
            nn.ReLU(),
            nn.Linear(ff_dim, embed_dim)
        )

        self.layernorm1 = nn.LayerNorm(embed_dim)
        self.layernorm2 = nn.LayerNorm(embed_dim)
        self.dropout1 = nn.Dropout(dropout_rate)
        self.dropout2 = nn.Dropout(dropout_rate)

    def forward(self, x: torch.Tensor, padding_mask: torch.Tensor = None) -> torch.Tensor:
        attn_output, _ = self.att(
            x, x, x,
            key_padding_mask=padding_mask  # masking
        )

        x = self.layernorm1(x + self.dropout1(attn_output))
        ffn_output = self.ffn(x)
        out = self.layernorm2(x + self.dropout2(ffn_output))
        return out


class SmallBERT(nn.Module):
    def __init__(self, sequence_length: int, vocab_size: int, embed_dim: int,
                 num_heads: int, ff_dim: int, num_layers: int) -> None:
        super().__init__()
        self.pos_embedding = PositionalEmbedding(sequence_length, vocab_size, embed_dim)
        self.blocks = nn.ModuleList([
            TransformerBlock(embed_dim, num_heads, ff_dim)
            for _ in range(num_layers)
        ])
        self.layernorm = nn.LayerNorm(embed_dim)
        self.dropout = nn.Dropout(0.1)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        x: (batch, seq_len) token ids
        """
        padding_mask = (x == 0)  # 0 = PAD  -> True masked in attn
        x = self.pos_embedding(x)

        for block in self.blocks:
            x = block(x, padding_mask=padding_mask)

        x = self.layernorm(x)
        return self.dropout(x)



class TextEncoder(nn.Module):
    def __init__(self, max_seq_len, vocab_size, embed_dim=128,
                 model_dim=128, num_heads=4, ff_dim=256, num_layers=2):
        super().__init__()
        self.token_emb = nn.Embedding(vocab_size, model_dim, padding_idx=0)
        self.pos_emb = nn.Embedding(max_seq_len, model_dim)

        encoder_layer = nn.TransformerEncoderLayer(
            d_model=model_dim,
            nhead=num_heads,
            dim_feedforward=ff_dim,
            batch_first=True,
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        self.proj = nn.Linear(model_dim, embed_dim)

    def forward(self, input_ids):
        """
        input_ids : [B, L] (padded, PAD = 0)
        """
        B, L = input_ids.shape
        device = input_ids.device

        positions = torch.arange(0, L, device=device).unsqueeze(0)  # [1, L]

        x = self.token_emb(input_ids) + self.pos_emb(positions)     # [B, L, d]
        x = self.encoder(x)                                         # [B, L, d]

        # mask pour ignorer le padding (token = 0)
        mask = (input_ids != 0).float()                             # [B, L]
        mask = mask.unsqueeze(-1)                                   # [B, L, 1]

        x_masked = x * mask                                         # [B, L, d]
        sum_emb = x_masked.sum(dim=1)                               # [B, d]
        lengths = mask.sum(dim=1).clamp(min=1e-6)                   # [B, 1]

        mean_emb = sum_emb / lengths                                # [B, d]
        emb = self.proj(mean_emb)                                   # [B, embed_dim] pas d'activation
        return emb

# %%
import numpy as np

class SmallCLIP(nn.Module):
    def __init__(self, vision_encoder, text_encoder, init_temperature=0.07):
        super().__init__()
        self.vision = vision_encoder
        self.text = text_encoder

        # log(1/T) clip openai
        self.logit_scale = nn.Parameter(torch.tensor(np.log(1.0 / init_temperature)))

    def forward(self, images, input_ids):
        """
        images : [B, 3, H, W]
        input_ids : [B, L]
        """
        img_emb = self.vision(images)      # [B, D]
        txt_emb = self.text(input_ids)     # [B, D]

        # Normalisation L2
        img_emb = F.normalize(img_emb, dim=-1)
        txt_emb = F.normalize(txt_emb, dim=-1)

        # Similarité
        logits = img_emb @ txt_emb.T       # [B, B]
        logits = logits * self.logit_scale.exp()

        return logits, img_emb, txt_emb

# %%
def clip_loss(logits):
    batch_size = logits.size(0) # [B x B]
    labels = torch.arange(batch_size, device=logits.device)
    
    # image > texte
    loss_i = F.cross_entropy(logits, labels)

    # texte > image
    loss_t = F.cross_entropy(logits.T, labels)

    return (loss_i + loss_t) / 2

# %%
def evaluate(model, dataloader, device, temperature: float):
    model.eval()
    total_loss = 0
    total_correct = 0
    total_samples = 0

    with torch.no_grad():
        for batch in dataloader:
            images = batch["image"].to(device)
            input_ids = batch["input_ids"].to(device)
            labels = batch["label"].to(device)

            logits, img_emb, text_emb = model(images, input_ids)

            loss = clip_loss(logits)
            
            total_loss += loss.item()

            # Predictions = argmax sur similarity matrix
            preds = logits.argmax(dim=1)

            total_correct += (preds == labels).sum().item()
            total_samples += labels.size(0)

    accuracy = total_correct / total_samples
    avg_loss = total_loss / len(dataloader)

    return avg_loss, accuracy

# %%
from sklearn.preprocessing import label_binarize

def get_predictions(model, dataloader, device, num_classes):
    model.eval()
    all_labels = []
    all_preds = []
    all_logits = []

    with torch.no_grad():
        for batch in dataloader:
            images = batch["image"].to(device)
            input_ids = batch["input_ids"].to(device)
            labels = batch["label"].to(device)

            logits, img_emb, text_emb = model(images, input_ids)
            
            print("\n")
            print(logits)
            print(img_emb)
            print(text_emb)
            print("\n")

            preds = logits.argmax(dim=1)

            all_labels.append(labels.cpu())
            all_preds.append(preds.cpu())
            all_logits.append(logits.cpu())

    all_labels = torch.cat(all_labels).numpy()
    all_preds = torch.cat(all_preds).numpy()
    all_logits = torch.cat(all_logits).numpy()

    # bin pour ROC multi-classe
    all_labels_bin = label_binarize(all_labels, classes=list(range(num_classes)))

    return all_labels, all_preds, all_logits, all_labels_bin

# %%
def get_embeddings(model, dataloader, device):
    model.eval()

    all_img_emb = []
    all_txt_emb = []
    all_labels = []

    with torch.no_grad():
        for batch in dataloader:
            images = batch["image"].to(device)
            input_ids = batch["input_ids"].to(device)
            labels = batch["label"]

            logits, img_emb, txt_emb = model(images, input_ids)
            loss = clip_loss(logits)
            all_img_emb.append(img_emb.cpu())
            all_txt_emb.append(txt_emb.cpu())
            all_labels.append(labels)

    return (
        torch.cat(all_img_emb, dim=0),
        torch.cat(all_txt_emb, dim=0),
        torch.cat(all_labels, dim=0)
    )

# %% [markdown]
# TsNE

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
def tsne_img_emb(img_emb, labels):
    tsne = TSNE(n_components=2, perplexity=10, learning_rate=200)
    img_2d = tsne.fit_transform(img_emb.numpy())

    plt.figure(figsize=(8,8))
    plt.scatter(img_2d[:,0], img_2d[:,1], c=labels, cmap='tab10')
    plt.title("t-SNE embeddings images")
    plt.colorbar()
    plt.show()

def tsne_txt_emb(txt_emb, labels):
    tsne = TSNE(n_components=2, perplexity=10, learning_rate=200)
    txt_2d = tsne.fit_transform(txt_emb.numpy())

    plt.figure(figsize=(8,8))
    plt.scatter(txt_2d[:,0], txt_2d[:,1], c=labels, cmap='tab10')
    plt.title("t-SNE embeddings textes")
    plt.colorbar()
    plt.show()

def tsne_duo(img_emb, txt_emb, labels):
    tsne = TSNE(n_components=2, perplexity=10, learning_rate=200)
    duo = img_emb + txt_emb
    txt_2d = tsne.fit_transform(duo.numpy())

    plt.figure(figsize=(8,8))
    plt.scatter(txt_2d[:,0], txt_2d[:,1], c=labels, cmap='tab10')
    plt.title("t-SNE embeddings textes")
    plt.colorbar()
    plt.show()


def tsne_combined(img_emb, txt_emb, labels):
    
    combined = torch.cat([img_emb, txt_emb], dim=0).numpy()
    labels_combined = torch.cat([labels, labels]).numpy()

    tsne = TSNE(n_components=2, perplexity=16, learning_rate=200)
    combined_2d = tsne.fit_transform(combined)

    plt.figure(figsize=(8,8))
    plt.scatter(combined_2d[:,0], combined_2d[:,1], c=labels_combined, cmap='tab10')
    plt.title("t-SNE embeddings IMAGE + TEXTE")
    plt.colorbar()
    plt.show()

# %%
model_clip = SmallCLIP(
    VisionEncoder(),
    TextEncoder(max_seq_len, vocab_size, 128, num_heads=4, ff_dim=256, num_layers=2)
)
device = "cuda" if torch.cuda.is_available() else "cpu"
model_clip.to(device)
img_emb, txt_emb, labels = get_embeddings(model_clip, val_loader, device)
tsne_img_emb(img_emb, labels)
tsne_txt_emb(txt_emb, labels)
tsne_combined(img_emb, txt_emb, labels)

# %%
def evaluate_clip(model, loader, device):
    model.eval()
    total_loss = 0
    n = 0

    with torch.no_grad():
        for batch in loader:
            images = batch["image"].to(device)
            input_ids = batch["input_ids"].to(device)

            logits, img_emb, txt_emb = model(images, input_ids)
            loss = clip_loss(logits)

            total_loss += loss.item() * images.size(0)
            n += images.size(0)

    return total_loss / n

# %%
from tqdm import tqdm

epochs = 20
device = "cuda" if torch.cuda.is_available() else "cpu"

embed_dim = 128
best_test_loss = float("inf")
patience = 5
wait = 0
best_state = None


vision_encoder = VisionEncoder(embed_dim=embed_dim)
text_encoder   = TextEncoder(max_seq_len, vocab_size, embed_dim=embed_dim)

model_clip = SmallCLIP(vision_encoder, text_encoder, init_temperature=0.07)
model_clip.to(device)

optimizer = torch.optim.Adam(model_clip.parameters(), lr=1e-4)
train_losses = []
test_losses = []
for epoch in range(epochs):
    model_clip.train()
    train_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs} - Train")

    total_train_loss = 0
    n_train = 0

    for batch in train_bar:
        images = batch["image"].to(device)
        input_ids = batch["input_ids"].to(device)

        logits, img_emb, txt_emb = model_clip(images, input_ids)
        loss = clip_loss(logits)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_train_loss += loss.item() * images.size(0)
        n_train += images.size(0)

        train_bar.set_postfix(loss=loss.item())

    train_loss = total_train_loss / n_train
    train_losses.append(train_loss)
    test_loss = -1
    test_loss = evaluate_clip(model_clip, val_loader, device)
    test_losses.append(test_loss)
    print(f"Epoch {epoch+1}/{epochs} | Train Loss: {train_loss:.4f} | Val Loss: {test_loss:.4f}")

    if test_loss < best_test_loss:
        print(f" Validation loss improved: {best_test_loss:.4f} : {test_loss:.4f}")
        best_test_loss = test_loss
        best_state = model_clip.state_dict()  
        wait = 0
    else:
        wait += 1
        print(f"Wait {wait}/{patience}")

        if wait >= patience:
            print("\nEarly stopping triggered!")
            break
# Out:
# Epoch 1/20 - Train:   0%|          | 0/35 [00:00<?, ?it/s]
# Epoch 1/20 - Train: 100%|██████████| 35/35 [00:03<00:00,  8.93it/s, loss=2.68]
# Epoch 1/20 | Train Loss: 2.7455 | Val Loss: 2.6052
#  Validation loss improved: inf : 2.6052
# Epoch 2/20 - Train: 100%|██████████| 35/35 [00:03<00:00,  9.35it/s, loss=1]
# Epoch 2/20 | Train Loss: 1.6765 | Val Loss: 2.6592
# Wait 1/5
# Epoch 3/20 - Train: 100%|██████████| 35/35 [00:03<00:00,  9.38it/s, loss=0.41]
# Epoch 3/20 | Train Loss: 0.3754 | Val Loss: 2.7072
# Wait 2/5
# Epoch 4/20 - Train: 100%|██████████| 35/35 [00:03<00:00,  9.38it/s, loss=0.0919]
# Epoch 4/20 | Train Loss: 0.1206 | Val Loss: 2.8489
# Wait 3/5
# Epoch 5/20 - Train: 100%|██████████| 35/35 [00:03<00:00,  9.40it/s, loss=0.03]
# Epoch 5/20 | Train Loss: 0.0502 | Val Loss: 2.7622
# Wait 4/5
# Epoch 6/20 - Train: 100%|██████████| 35/35 [00:03<00:00,  9.35it/s, loss=0.0276]
# Epoch 6/20 | Train Loss: 0.0348 | Val Loss: 2.7047
# Wait 5/5
#
# Early stopping triggered!

# %%
plt.figure(figsize=(10,5))
plt.plot(train_losses, label="Train Loss")
plt.plot(test_losses, label="Val Loss")
plt.xlabel("Epoch")
plt.ylabel("Contrastive Loss")
plt.title("CLIP Training & Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
for batch in val_loader:
    print(batch)
img_emb, txt_emb, labels = get_embeddings(model_clip, val_loader, device)
tsne_img_emb(img_emb, labels)
tsne_txt_emb(txt_emb, labels)
tsne_combined(img_emb, txt_emb, labels)
# Out:
# {'caption': ['The tennis player, a young Asian athlete with a focused expression, crouches low to return a serve from her opponent on the opposite side of the court. The ball flies towards her, its trajectory arcing sharply as it approaches the net. With a swift motion, she reaches out and contacts the ball with her racket, sending it back over the net in a fierce and precise reply.', 'A group of bicyclists in a race, their sleek road bikes speeding down the winding course as they compete for the top finish. The sun beats down on the pavement, casting long shadows behind the riders as they pedal furiously through the turn. In the distance, a crowd cheers them on, their voices carrying above the sound of wheels on asphalt.', 'A young boy, laughing as he tries to shake off the soaking wet clothes, stands in the downpour with his arms raised in surrender. Rainwater pours off the brim of his cap and drips from the tip of his nose. The sound of raindrops hitting the pavement creates a soothing melody in the background.', "The man in the beret pedaled his bicycle down the cobblestone street, weaving past pedestrians who stopped to glance at the colorful market stalls set up along the way. A few children played tag on the sidewalk, their laughter carrying through the crisp morning air as they chased each other towards the city square. The sun cast a warm glow over the scene, illuminating the vibrant flowers arranged in a nearby vendor's cart.", 'A playful black labrador mix and his brown companion are chasing each other in circles, their paws sinking into the warm, golden sand of the beach. The sun shines brightly overhead, casting a gentle glow over the scene as the two dogs frolic and play together. Seagulls fly overhead, watching the commotion with interest from above.', "Outside a primary school, a group of children in their uniforms stand eagerly beside a small playground, chatting excitedly with each other as they wait for recess to begin. Amidst them, a fluffy golden retriever wagging its tail joyfully plays catch with one of the kids, adding to the lively atmosphere of the morning scene. The dog's owner, a smiling teacher, watches over the children from a nearby bench, making sure everyone stays safe and happy.", 'A young bike rider has taken to the air above a makeshift ramp in a skatepark, their boarder-style bicycle soaring through the mid-air as they perform a daring trick. The ramp stretches out before them, a long, curved concrete slope that provides the perfect launchpad for this aerial stunt. A few onlookers stand nearby, cheering and snapping photos of the impressive feat.', "A playful scene unfolds in a sun-dappled park on a warm afternoon. A woman, dressed in a black skirt and blue shirt with a beige vest, stands with her back to the camera, holding a ball in mid-air as if about to toss it for her energetic canine companion, who is jumping up excitedly, its paws waving wildly as it strains to catch the ball. The woman's laughter carries through the air as she prepares for another playful throw.", "A young boy giggles uncontrollably as he rolls around in a giant pit filled with dozens of vibrant blue exercise balls, their bouncy texture making every step feel like a trampoline under his feet. His bright smile and flushed cheeks showcase the joy of playing in this unusual playground feature. Nearby, a patient adult or caregiver offers a reassuring hand to help him out when he's ready to stop bouncing around.", "A Jeep, its once shiny surface now caked in mud, slowly navigates through the murky waters of a muddy riverbed. The surrounding landscape appears to be a rural or wilderness area, with tall trees and overgrown vegetation visible on the riverbanks. As the vehicle continues to make its way deeper into the water, it's clear that the driver is attempting to cross the river rather than just wading through it.", 'A group of boys in a local soccer league are gathered on the field, their bright team hats a stark contr ...
#           [-1.9124, -1.8782, -1.8610,  ..., -2.1179, -2.1179, -2.1008],
#           [-2.0152, -1.9638, -1.9638,  ..., -2.1179, -2.1179, -2.1008],
#           ...,
#           [ 0.6049,  0.6906,  0.8618,  ...,  1.5982,  1.5297,  1.5297],
#           [ 0.3309,  0.3138,  0.3994,  ...,  1.5982,  1.5468,  1.5297],
#           [ 0.5193,  0.5536,  0.6906,  ...,  1.5810,  1.5468,  1.4612]],
#
#          [[-0.4251, -0.4426, -0.4251,  ..., -0.8277, -0.8803, -0.8978],
#           [-0.4951, -0.4601, -0.4426,  ..., -0.8277, -0.8803, -0.8978],
#           [-0.5651, -0.4951, -0.5126,  ..., -0.8452, -0.8803, -0.8978],
#           ...,
#           [-0.6176, -0.5301, -0.3901,  ...,  0.2577,  0.2227,  0.2402],
#           [-0.8102, -0.8452, -0.7927,  ...,  0.2577,  0.2052,  0.2052],
#           [-0.6352, -0.6001, -0.5126,  ...,  0.2402,  0.1877,  0.1001]],
#
#          [[-0.7238, -0.7413, -0.7238,  ..., -1.0724, -1.1073, -1.1247],
#           [-0.7936, -0.7587, -0.7413,  ..., -1.0724, -1.1073, -1.1247],
#           [-0.8807, -0.8284, -0.8284,  ..., -1.0898, -1.1073, -1.1247],
#           ...,
#           [-0.7587, -0.6890, -0.5670,  ...,  0.0082, -0.0441, -0.0267],
#           [-0.9504, -1.0027, -0.9330,  ...,  0.0082, -0.0441, -0.0615],
#           [-0.7936, -0.7587, -0.6715,  ..., -0.0092, -0.0441, -0.1487]]],
#
#
#         [[[-1.7583, -1.7583, -1.7754,  ...,  1.1358,  0.7591,  0.0056],
#           [-1.8439, -1.8782, -1.9124,  ...,  1.1700,  0.7933,  0.0569],
#           [-1.9638, -1.9467, -1.9295,  ...,  1.1872,  0.8104,  0.0912],
#           ...,
#           [ 1.6495,  1.6495,  1.6324,  ...,  0.9132,  0.8276,  0.7933],
#           [ 1.7694,  1.7694,  1.7865,  ...,  0.8447,  0.8276,  0.8789],
#           [ 1.7009,  1.7180,  1.7352,  ...,  0.7762,  0.8276,  0.7591]],
#
#          [[-1.5105, -1.5105, -1.5280,  ...,  0.6604,  0.4153, -0.2500],
#           [-1.5980, -1.6331, -1.6681,  ...,  0.6954,  0.4503, -0.2150],
#           [-1.7206, -1.7031, -1.6856,  ...,  0.6779,  0.4678, -0.1975],
#           ...,
#           [ 1.4482,  1.4482,  1.4482,  ...,  0.6954,  0.5728,  0.5553],
#           [ 1.6758,  1.6758,  1.6933,  ...,  0.5903,  0.5728,  0.5903],
#           [ 1.6583,  1.6758,  1.6933,  ...,  0.5028,  0.5553,  0.4678]],
#
#          [[-1.6476, -1.6476, -1.6476,  ..., -0.0441, -0.2707, -0.8458],
#           [-1.6824, -1.7347, -1.7696,  ..., -0.0092, -0.2184, -0.7936],
#           [-1.7696, -1.7696, -1.7522,  ...,  0.0082, -0.2010, -0.7761],
#           ...,
#           [ 1.4374,  1.4374,  1.4200,  ...,  0.4962,  0.3742,  0.3219],
#           [ 1.5594,  1.5594,  1.5942,  ...,  0.3916,  0.3742,  0.4265],
#           [ 1.4897,  1.5071,  1.5420,  ...,  0.3045,  0.3568,  0.2871]]],
#
#
#         [[[-0.2513, -0.1657, -0.1828,  ..., -0.7308, -0.6281, -0.5424],
#           [-0.2684, -0.1486, -0.1143,  ...,  0.2282,  0.2453,  0.2624],
#           [-0.2513, -0.1486, -0.0972,  ...,  0.0741,  0.0741,  0.0569],
#           ...,
#           [-0.3198, -0.2856, -0.2684,  ..., -0.5767, -0.4397, -0.3883],
#           [-0.3369, -0.3027, -0.2684,  ..., -0.5596, -0.4226, -0.3027],
#           [-0.3369, -0.3027, -0.2684,  ..., -0.6452, -0.5767, -0.4568]],
#
#          [[ 0.5203,  0.6078,  0.5903,  ...,  0.0826,  0.1877,  0.2577],
#           [ 0.5028,  0.6254,  0.6604,  ...,  0.9930,  1.0105,  1.0280],
#           [ 0.5203,  0.6254,  0.6779,  ...,  0.7829,  0.7654,  0.7479],
#           ...,
#           [ 0.5028,  0.5378,  0.5553,  ...,  0.1702,  0.3102,  0.3627],
#           [ 0.4678,  0.5028,  0.5378,  ...,  0.1877,  0.3277,  0.4503],
#           [ 0.4678,  0.5028,  0.5378,  ...,  0.1001,  0.1702,  0.2927]],
#
#          [[ 1.1934,  1.2805,  1.2631,  ...,  0.6531,  0.7576,  0.8274],
#           [ 1.1759,  1.2980,  1.3328,  ...,  1.5245,  1.5594,  1.5594],
#           [ 1.1934,  1.2980,  1.3502,  ...,  1.2282,  1.2282,  1.2282],
#           ...,
#           [ 1.1759,  1.2108,  1.2282,  ...,  0.9842,  1.1237,  1.1759],
#           [ 1.1934,  1.2108,  1.2457,  ...,  1.0017,  1.1411,  1.2631],
#           [ 1.1934,  1.2282,  1.2631,  ...,  0.9145,  0.9842,  1.1062]]],
#
#
#         ...,
#
#
#         [[[ 0.0569,  0.2967,  0.1768,  ..., -0.4568, -0.6281,  0.8276],
#           [ 0.5022,  0.1939,  0.4851,  ..., -0.3027, -0.9363,  0.2624],
#           [-0.1828,  0.4508,  0.4679,  ...,  0.0741, -0.5596,  0.4166],
#           ...,
#           [ 0.6392,  0.5022,  0.3138,  ...,  0.0912,  0.5707, -0.2342],
#           [-0.1486, -0.8507,  0.5536,  ...,  0.0569,  0.6221,  0.5536],
#           [-0.7650, -0.5596,  0.1254,  ...,  0.5878,  0.9817,  0.8961]],
#
#          [[ 0.0651,  0.3102,  0.1527,  ..., -0.6001, -0.7927,  0.6779],
#           [ 0.5028,  0.2052,  0.4503,  ..., -0.4426, -1.1078,  0.0826],
#           [-0.2500,  0.4503,  0.4503,  ..., -0.0574, -0.7577,  0.2227],
#           ...,
#           [ 0.8880,  0.7654,  0.5903,  ...,  0.4853,  0.9405,  0.1176],
#           [ 0.0651, -0.6176,  0.8354,  ...,  0.4328,  0.9405,  0.8704],
#           [-0.5651, -0.3200,  0.3978,  ...,  0.9580,  1.2906,  1.1856]],
#
#          [[-0.2532,  0.1302,  0.0605,  ..., -0.3055, -0.6715,  0.7228],
#           [ 0.2173,  0.0431,  0.3742,  ..., -0.1661, -0.9330,  0.1302],
#           [-0.4798,  0.3219,  0.3916,  ...,  0.2173, -0.6541,  0.2522],
#           ...,
#           [ 0.5136,  0.2871,  0.0082,  ..., -0.1138,  0.2871, -0.5844],
#           [-0.2881, -1.0201,  0.2522,  ..., -0.1661,  0.3393,  0.2173],
#           [-0.8807, -0.7761, -0.1835,  ...,  0.3742,  0.7228,  0.5834]]],
#
#
#         [[[-1.0733, -1.0733, -1.0562,  ..., -0.1828, -0.2342, -0.2513],
#           [-0.9705, -1.1075, -0.9877,  ..., -0.1828, -0.2342, -0.2513],
#           [-0.9020, -1.1247, -1.0390,  ..., -0.1828, -0.2342, -0.2513],
#           ...,
#           [-1.2959, -1.5185, -1.1589,  ..., -0.2171, -0.1486, -0.0801],
#           [-1.2274, -1.2959, -0.9534,  ..., -0.8849,  0.1083,  0.2111],
#           [-1.3987, -1.1589, -1.3302,  ..., -0.9877, -0.2513, -0.1828]],
#
#          [[-0.7577, -0.8452, -0.9153,  ...,  0.1527,  0.1176,  0.1001],
#           [-0.6527, -0.8627, -0.8277,  ...,  0.1527,  0.1176,  0.1001],
#           [-0.5651, -0.8277, -0.8102,  ...,  0.1527,  0.1176,  0.1001],
#           ...,
#           [-1.2304, -1.4055, -0.9853,  ..., -0.3550, -0.3375, -0.3025],
#           [-1.1253, -1.1779, -0.7752,  ..., -0.9678, -0.1099, -0.0749],
#           [-1.3354, -1.0378, -1.1604,  ..., -0.9678, -0.4426, -0.4951]],
#
#          [[-0.2358, -0.4101, -0.6367,  ...,  0.6531,  0.6356,  0.6182],
#           [-0.1487, -0.4275, -0.5321,  ...,  0.6531,  0.6356,  0.6008],
#           [-0.0615, -0.3927, -0.4798,  ...,  0.6356,  0.6182,  0.6008],
#           ...,
#           [-1.2467, -1.4559, -1.1421,  ..., -0.5844, -0.6018, -0.5670],
#           [-1.0898, -1.2119, -0.9156,  ..., -1.1944, -0.4624, -0.4450],
#           [-1.2467, -1.0550, -1.2990,  ..., -1.1944, -0.8110, -0.8807]]],
#
#
#         [[[ 0.0741,  0.0741,  0.1083,  ..., -0.0116, -0.0287, -0.0116],
#           [ 0.0912,  0.0569,  0.0912,  ..., -0.0287, -0.0116,  0.0056],
#           [ 0.1254,  0.1254,  0.1083,  ..., -0.0629, -0.0287, -0.0116],
#           ...,
#           [ 0.4166,  0.5536,  0.5536,  ..., -0.0629,  0.1597,  0.1597],
#           [ 0.5364,  0.7591,  1.0673,  ...,  0.0569,  0.3652,  0.3994],
#           [ 0.7933,  1.2557,  1.6324,  ...,  0.6221,  0.2453,  0.5022]],
#
#          [[ 0.3627,  0.3627,  0.3627,  ...,  0.3627,  0.3452,  0.3452],
#           [ 0.3452,  0.3627,  0.3627,  ...,  0.3452,  0.3627,  0.3627],
#           [ 0.3978,  0.3978,  0.3978,  ...,  0.3277,  0.3452,  0.3627],
#           ...,
#           [ 0.5378,  0.7129,  0.8004,  ...,  0.4503,  0.5903,  0.5728],
#           [ 0.6779,  0.9230,  1.2731,  ...,  0.5203,  0.7129,  0.6954],
#           [ 0.9755,  1.4307,  1.7983,  ...,  1.0455,  0.5378,  0.7479]],
#
#          [[-0.5495, -0.5844, -0.6018,  ..., -0.8981, -0.8807, -0.8284],
#           [-0.6018, -0.6193, -0.6367,  ..., -0.9156, -0.8981, -0.8633],
#           [-0.6541, -0.6715, -0.6541,  ..., -0.9504, -0.9504, -0.9504],
#           ...,
#           [-0.6367, -0.3404, -0.1835,  ..., -0.7936, -0.5495, -0.5495],
#           [-0.4275, -0.0267,  0.4439,  ..., -0.6715, -0.3927, -0.3927],
#           [-0.0615,  0.5834,  1.1237,  ..., -0.0615, -0.6193, -0.4450]]]]), 'input_ids': tensor([[  2, 318, 215,  ...,   0,   0,   0],
#         [  3, 185,   4,  ...,   0,   0,   0],
#         [  3,  38,  66,  ...,   0,   0,   0],
#         ...,
#         [  5,   2, 457,  ...,   0,   0,   0],
#         [  2, 230,  52,  ...,   0,   0,   0],
#         [  3, 108,  32,  ...,   0,   0,   0]]), 'label': tensor([0, 1, 3, 1, 2, 2, 1, 0, 0, 3, 0, 2, 0, 0, 0, 2])}
# {'caption': ['A young boy, his eyes fixed on the ball in his paws, charges out of the calm morning surf as he playfully runs alongside his energetic black and brown dog. The warm sunlight catches the waves as they lap gently at the shore, and the sound of seagulls fills the air. In a split second, the dog will be off to retrieve the ball, sending them both tumbling onto the sandy beach in a joyful heap.', "A playful black dog, its fur fluffed up from the ocean breeze, runs swiftly across the sandy beach, its tail wagging excitedly as it chases after a seagull. The warm sunlight casts a golden glow on the scene, illuminating the grains of sand that dance around the dog's paws with each step. In the distance, the sound of waves gently lapping at the shore creates a soothing melody that seems to match the dog's carefree rhythm.", "A cyclist clad in a bright blue jacket, wearing a sturdy bicycle helmet, pedals down a scenic coastal path, the wind blowing through their hair as they take in the breathtaking ocean views on one side and lush greenery on the other. The bike's tires hum smoothly over the well-maintained pavement, its sleek frame reflecting the sunlight as it glides effortlessly towards the distant horizon. The rider's relaxed posture suggests a familiar route, a sense of freedom and joy evident in every stroke of the pedals.", 'A rugged dirt path winds through a sun-drenched landscape, flanked by tall trees and rocky outcroppings. A man in blue jeans and a worn jacket stands atop his bike, the engine revving as he prepares to launch himself over a small jump. The scene is one of high-octane freedom, with the thrill of off-road adventure palpable in every detail.', 'A woman in a bold outfit pedals her sleek bicycle down a bustling city street, drawing curious glances from passersby. On her back, she wears a pair of black, intricately designed wings attached to a gleaming metal frame, which seems almost too heavy for its delicate attachment points. Nearby pedestrians exchange knowing smiles and nods as they continue on their own daily routines.', "A girl clad in a reflective jacket pedals her bike along a dimly lit street, the wheels humming softly on the pavement as she makes her way home from a late-night ride with friends. The streetlights cast long shadows behind the parked cars and buildings, creating an eerie yet peaceful atmosphere. A faint glow emanates from the nearby houses, illuminating the girl's determined face as she navigates through the quiet evening streets.", 'A serene riverbank scene unfolds, with sunlight filtering through the trees above. A man stands waist-deep in the calm waters, his fly fishing rod cast out into the gentle current as he waits for a bite. The soft ripples on the surface of the river create a soothing melody that echoes through the peaceful surroundings.', 'A young girl, dressed in a crisp white coat, stands playfully in the center of a serene fountain, surrounded by gently splashing water. The sun casts a warm glow on the scene, causing the droplets to sparkle like tiny diamonds. Meanwhile, her friend, a boy with an infectious grin, looks on from the background, clearly enjoying the impromptu water feature that has brought so much joy to their afternoon.', "A young boy, enthusiastically wearing a New York Mets baseball jersey, stands proudly on his shiny bike in front of a suburban house with a neatly manicured lawn and a few trees lining the sidewalk. The bright blue sky above adds to the sense of joy and freedom that comes with riding a bike on a sunny day. A few leaves from the nearby trees are scattered around the boy's feet, adding a touch of autumnal color to the scene.", "A playful Corgi bursts out of a colorful tunnel, its little legs moving quickly as it emerges into a bright backyard filled with lush green grass and vibrant flowers. The sun casts a warm glow over the scene, highlighting the dog's fluffy fur as it dashes around in excitement. In the background, a few toys c ...
#           [-0.0458, -0.0629, -0.0629,  ..., -0.6109, -0.5938, -0.5938],
#           [-0.0116, -0.0458, -0.1657,  ..., -0.4911, -0.5082, -0.5424],
#           ...,
#           [ 0.0569, -0.0629,  0.0912,  ..., -0.0287,  0.0056,  0.0056],
#           [ 0.0227, -0.0972,  0.0227,  ...,  0.0056,  0.0227,  0.0398],
#           [ 0.1426,  0.1768,  0.1768,  ...,  0.2282,  0.2111,  0.2967]],
#
#          [[ 0.4328,  0.3978,  0.3102,  ..., -0.2500, -0.2150, -0.1625],
#           [ 0.3452,  0.3277,  0.3277,  ..., -0.2500, -0.1975, -0.1625],
#           [ 0.3803,  0.3452,  0.2227,  ..., -0.1099, -0.1099, -0.1275],
#           ...,
#           [ 0.0476, -0.0749,  0.0826,  ..., -0.0224,  0.0651,  0.0651],
#           [ 0.0476, -0.0749,  0.0651,  ...,  0.0476,  0.1001,  0.1352],
#           [ 0.2227,  0.2402,  0.2227,  ...,  0.2927,  0.3102,  0.3978]],
#
#          [[ 0.7751,  0.7402,  0.6531,  ..., -0.0267, -0.0267,  0.0256],
#           [ 0.6879,  0.6705,  0.6705,  ..., -0.0092,  0.0431,  0.0779],
#           [ 0.7228,  0.6879,  0.5659,  ...,  0.1999,  0.1825,  0.1651],
#           ...,
#           [ 0.2348,  0.1302,  0.2871,  ...,  0.1825,  0.3045,  0.3045],
#           [ 0.2696,  0.1476,  0.2871,  ...,  0.2696,  0.3568,  0.4091],
#           [ 0.4614,  0.4962,  0.4788,  ...,  0.5485,  0.5834,  0.6705]]],
#
#
#         [[[-1.4329, -1.2617, -1.3644,  ..., -1.9124, -1.9467, -1.9295],
#           [-1.1247, -1.0390, -1.2274,  ..., -1.7583, -1.7754, -1.7583],
#           [-0.7993, -0.7650, -0.9363,  ..., -1.4158, -1.4329, -1.4329],
#           ...,
#           [-0.6965, -0.1828, -0.1143,  ..., -0.1143, -0.1314, -0.3198],
#           [-0.4397, -0.1486,  0.1597,  ..., -0.1828, -0.1143, -0.2342],
#           [-0.1486, -0.1314,  0.0227,  ..., -0.2684, -0.0801, -0.3541]],
#
#          [[-1.3354, -1.1604, -1.2654,  ..., -1.6506, -1.6856, -1.6856],
#           [-1.0028, -0.9153, -1.1253,  ..., -1.5630, -1.5805, -1.5805],
#           [-0.6702, -0.6176, -0.8277,  ..., -1.3004, -1.3354, -1.3354],
#           ...,
#           [-0.6877, -0.1450, -0.0399,  ..., -0.0049, -0.0224, -0.1975],
#           [-0.4426, -0.1099,  0.2402,  ..., -0.1099, -0.0399, -0.1625],
#           [-0.1275, -0.0749,  0.1176,  ..., -0.2150, -0.0049, -0.2675]],
#
#          [[-1.5953, -1.3687, -1.4384,  ..., -1.5953, -1.6127, -1.5953],
#           [-1.3687, -1.2641, -1.4210,  ..., -1.5953, -1.5953, -1.5779],
#           [-1.2293, -1.1770, -1.3339,  ..., -1.5081, -1.4907, -1.4559],
#           ...,
#           [-1.3513, -0.8981, -0.8633,  ..., -0.8110, -0.8981, -1.1073],
#           [-1.0898, -0.8981, -0.6367,  ..., -0.9156, -0.9504, -1.0898],
#           [-0.8807, -0.9504, -0.8458,  ..., -1.0027, -0.8807, -1.1421]]],
#
#
#         [[[-0.7822, -0.7993, -0.8164,  ..., -1.5699, -1.5870, -1.6213],
#           [-0.8849, -0.8849, -0.9020,  ..., -1.5870, -1.5870, -1.6213],
#           [-0.9877, -0.9363, -0.8678,  ..., -1.5528, -1.6213, -1.6555],
#           ...,
#           [-0.5253, -0.5082, -0.4568,  ..., -0.7308, -0.0801,  0.2282],
#           [-0.2684, -0.2513, -0.2171,  ..., -0.4568,  0.3138,  0.4166],
#           [-0.0458, -0.0629, -0.0287,  ..., -0.4911,  0.0056,  0.0912]],
#
#          [[-0.9503, -0.9678, -0.9853,  ..., -1.4930, -1.4755, -1.5105],
#           [-1.0553, -1.0553, -1.0728,  ..., -1.5105, -1.4755, -1.5105],
#           [-1.1604, -1.1078, -1.0378,  ..., -1.4755, -1.5105, -1.5455],
#           ...,
#           [-0.9678, -0.9678, -0.9153,  ..., -0.9678, -0.3901, -0.0749],
#           [-0.7052, -0.6877, -0.6527,  ..., -0.6877,  0.0651,  0.1702],
#           [-0.4601, -0.4776, -0.4601,  ..., -0.7402, -0.2500, -0.1450]],
#
#          [[-0.9504, -0.9678, -0.9853,  ..., -1.3339, -1.3513, -1.3861],
#           [-1.0550, -1.0550, -1.0724,  ..., -1.3513, -1.3513, -1.3687],
#           [-1.1596, -1.1073, -1.0376,  ..., -1.3164, -1.3687, -1.4036],
#           ...,
#           [-1.0898, -1.0898, -1.0550,  ..., -0.6367, -0.1661,  0.0779],
#           [-0.8981, -0.8807, -0.8458,  ..., -0.3753,  0.1302,  0.1476],
#           [-0.7064, -0.7238, -0.7238,  ..., -0.4275, -0.2184, -0.2532]]],
#
#
#         ...,
#
#
#         [[[ 0.6734,  0.7591,  0.6563,  ...,  0.2453,  0.6049,  0.3481],
#           [-1.4500, -1.0733, -0.8335,  ...,  0.6563,  0.7419,  0.7762],
#           [-1.3130, -1.4329, -1.3473,  ...,  0.3823,  0.6906,  0.6734],
#           ...,
#           [-0.0116, -0.0287, -0.3883,  ..., -1.2274, -1.5699, -1.4672],
#           [-0.4739, -0.2856, -0.7137,  ..., -1.2274, -1.4158, -1.5699],
#           [-0.9192, -1.0048, -1.2788,  ..., -1.4329, -1.5357, -1.4843]],
#
#          [[ 1.0630,  1.0805,  0.9055,  ...,  0.4328,  0.5378,  0.1877],
#           [-1.2304, -0.8452, -0.6352,  ...,  0.7829,  0.7829,  0.7829],
#           [-1.1779, -1.2829, -1.1604,  ...,  0.3978,  0.8179,  0.8529],
#           ...,
#           [ 0.4678,  0.5028,  0.3102,  ..., -0.1099, -0.4076, -0.3200],
#           [ 0.0826,  0.3452,  0.0126,  ..., -0.0924, -0.3550, -0.6001],
#           [-0.2850, -0.2850, -0.4951,  ..., -0.2675, -0.5301, -0.5651]],
#
#          [[-0.1835,  0.0605, -0.0267,  ..., -0.6890, -0.3055, -0.5321],
#           [-1.6127, -1.4210, -1.4384,  ..., -0.3055, -0.0790,  0.0256],
#           [-1.5953, -1.7870, -1.8044,  ..., -0.6367, -0.0441,  0.0779],
#           ...,
#           [ 0.1825,  0.0953, -0.2707,  ..., -0.8633, -1.1770, -1.0898],
#           [-0.2707, -0.1138, -0.6018,  ..., -0.8807, -1.1073, -1.2816],
#           [-0.7064, -0.8110, -1.1596,  ..., -1.0898, -1.2641, -1.2467]]],
#
#
#         [[[-0.9534, -0.9705, -1.0219,  ..., -1.6213, -1.7412, -1.7754],
#           [-1.1247, -1.1418, -1.1760,  ..., -1.6727, -1.7583, -1.7925],
#           [-1.2959, -1.2959, -1.3473,  ..., -1.7069, -1.7754, -1.8097],
#           ...,
#           [-1.5357, -1.6384, -1.6384,  ..., -1.8953, -1.9295, -1.9467],
#           [-1.7754, -1.6555, -1.6555,  ..., -1.9295, -1.9809, -2.0152],
#           [-1.7069, -1.7069, -1.6555,  ..., -1.9980, -2.0152, -2.0323]],
#
#          [[-0.1800, -0.2150, -0.2675,  ..., -1.0028, -1.1429, -1.1779],
#           [-0.3200, -0.3550, -0.4076,  ..., -1.0553, -1.1604, -1.1954],
#           [-0.4776, -0.4951, -0.5476,  ..., -1.0903, -1.1779, -1.2129],
#           ...,
#           [-0.8978, -1.0203, -1.0378,  ..., -1.6681, -1.7206, -1.7381],
#           [-1.1253, -1.0203, -1.0203,  ..., -1.7031, -1.7556, -1.7906],
#           [-1.0553, -1.0378, -0.9678,  ..., -1.7556, -1.7731, -1.8081]],
#
#          [[ 0.8971,  0.9145,  0.8622,  ..., -0.0790, -0.1835, -0.2184],
#           [ 0.7925,  0.7751,  0.7402,  ..., -0.1487, -0.2184, -0.2358],
#           [ 0.6879,  0.6705,  0.6356,  ..., -0.1835, -0.2358, -0.2532],
#           ...,
#           [ 1.0888,  0.9494,  0.9145,  ...,  0.2522,  0.0953,  0.0256],
#           [ 0.8622,  0.9494,  0.9319,  ...,  0.2173,  0.0082, -0.0790],
#           [ 0.8448,  0.8448,  0.8971,  ...,  0.1651, -0.0615, -0.1661]]],
#
#
#         [[[-0.3369, -0.5082, -0.3712,  ..., -1.5870, -1.5185, -1.5185],
#           [ 0.0227, -0.5253, -1.1760,  ..., -1.6213, -1.5528, -1.5357],
#           [-0.8335, -0.8335, -0.9705,  ..., -1.6555, -1.5870, -1.5699],
#           ...,
#           [-1.8097, -1.6213, -1.7925,  ..., -1.2274, -1.3130, -1.4158],
#           [-1.6042, -1.6727, -1.8782,  ..., -1.5870, -1.7240, -1.6898],
#           [-1.7240, -1.6042, -1.4500,  ..., -2.0494, -1.9980, -1.7754]],
#
#          [[ 0.0651, -0.1099, -0.0049,  ..., -1.4755, -1.4055, -1.4055],
#           [ 0.3978, -0.1800, -0.8627,  ..., -1.5105, -1.4405, -1.4230],
#           [-0.5476, -0.5476, -0.7052,  ..., -1.5455, -1.4755, -1.4580],
#           ...,
#           [-1.6506, -1.4405, -1.6155,  ..., -1.0903, -1.1954, -1.2829],
#           [-1.4580, -1.5280, -1.7381,  ..., -1.4580, -1.5980, -1.5630],
#           [-1.5805, -1.4580, -1.3004,  ..., -1.9482, -1.8782, -1.6506]],
#
#          [[-1.3687, -1.4733, -1.2816,  ..., -1.5081, -1.5081, -1.5256],
#           [-0.8633, -1.3339, -1.6127,  ..., -1.5430, -1.5256, -1.5256],
#           [-1.4384, -1.3861, -1.4384,  ..., -1.5779, -1.5604, -1.5430],
#           ...,
#           [-1.6824, -1.5430, -1.6999,  ..., -1.1247, -1.2119, -1.2641],
#           [-1.5430, -1.6127, -1.7522,  ..., -1.4036, -1.5430, -1.5430],
#           [-1.6824, -1.5604, -1.4036,  ..., -1.8044, -1.7870, -1.6476]]]]), 'input_ids': tensor([[  3,  38,  66,  ...,   0,   0,   0],
#         [  3,  40,  32,  ...,   0,   0,   0],
#         [  3, 272, 162,  ...,   0,   0,   0],
#         ...,
#         [  3,  40,  32,  ...,   0,   0,   0],
#         [  3,  38, 355,  ...,   0,   0,   0],
#         [  2, 161, 180,  ...,   0,   0,   0]]), 'label': tensor([0, 2, 1, 1, 1, 1, 3, 3, 1, 2, 0, 3, 0, 0, 3, 1])}

# %%
def retrieval_accuracy(model, dataloader, device):
    model.eval()
    all_img_emb = []
    all_txt_emb = []

    with torch.no_grad():
        for batch in dataloader:
            images = batch["image"].to(device)
            input_ids = batch["input_ids"].to(device)

            _, img_emb, txt_emb = model(images, input_ids)
            img_emb = F.normalize(img_emb, dim=-1)
            txt_emb = F.normalize(txt_emb, dim=-1)

            all_img_emb.append(img_emb.cpu())
            all_txt_emb.append(txt_emb.cpu())

    img_emb = torch.cat(all_img_emb)   # [N, D]
    txt_emb = torch.cat(all_txt_emb)   # [N, D]

    sims = img_emb @ txt_emb.T         # [N, N]
    preds = sims.argmax(dim=1)

    labels = torch.arange(len(img_emb))

    acc = (preds == labels).float().mean().item()
    return acc

# %%
print(retrieval_accuracy(model_clip, train_loader, device))
print(retrieval_accuracy(model_clip, test_loader, device))
# print(retrieval_accuracy(model_clip, val_loader, device))
# Out:
# 1.0
# 0.0416666679084301

# %%
def compute_image_embeddings(model, dataloader, device):
    model.eval()
    all_img_embs = []
    all_images    = []   
    all_indices   = []

    with torch.no_grad():
        for batch in dataloader:
            images = batch["image"].to(device)         # [B, 3, 224, 224]
            indices = batch["index"]                   # [B]

            # Embedding des images 
            img_emb = model.vision(images)             # [B, D]
            # img_emb = F.normalize(img_emb, dim=-1)

            # Stockage embeddings
            all_img_embs.append(img_emb.cpu())

            # Stockage images 
            for img in batch["image"]:                # img : [3,224,224]
                all_images.append(img)                # on stocke l’image brute

            all_indices.extend(indices.tolist())

    # Concat embeddings seulement (images = liste)
    all_img_embs = torch.cat(all_img_embs, dim=0)       # [N, D]

    return all_img_embs, all_images, all_indices


def text_to_topk_images(model, text, tokenizer, max_seq_len, all_img_embs,
                        all_img_paths, k=5, device="cuda"):
    model.eval()

    seq = tokenizer.texts_to_sequences([text])
    padded = pad_sequences(seq, maxlen=max_seq_len, padding="post")
    txt_ids = torch.tensor(padded).to(device)

    with torch.no_grad():
        _, txt_emb = None, model.text(txt_ids)
        txt_emb = F.normalize(txt_emb[0], dim=-1)

        img_embs = F.normalize(all_img_embs.to(device), dim=-1)
        sims = img_embs @ txt_emb

        topk_vals, topk_idx = sims.topk(k)
        topk_paths = [all_img_paths[i] for i in topk_idx.cpu().tolist()]

    return topk_paths, topk_vals.cpu()


all_img_embs, all_img_paths, all_indices= compute_image_embeddings(model_clip, test_loader, device)
top_paths, top_vals = text_to_topk_images(model_clip, "The dog is in the water", tokenizer, max_seq_len, all_img_embs, all_img_paths)
for img_tensor, score in zip(top_paths, top_vals):
    img = img_tensor.permute(1, 2, 0).cpu().numpy()
    plt.imshow(img)
    plt.title(f"score: {score:.3f}")
    plt.axis("off")
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9124069..2.6051416].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.1007793..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.1007793..2.5702832].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8610327..2.465708].

# %%
def compute_text_embeddings(model, dataloader, device):
    model.eval()
    all_txt_embs = []
    all_captions = []

    with torch.no_grad():
        for batch in dataloader:
            # Captions brutes (strings)
            captions = batch["caption"]           # liste de length B
            input_ids = batch["input_ids"].to(device)  # [B, L]

            # Embeddings textuels SEULS (pas besoin d'images)
            txt_emb = model.text(input_ids)       # [B, D]
            txt_emb = F.normalize(txt_emb, dim=-1)

            # stockage
            all_txt_embs.append(txt_emb.cpu())
            all_captions.extend(captions)

    # concatène toutes les batches
    all_txt_embs = torch.cat(all_txt_embs, dim=0)     # [N, D]

    return all_txt_embs, all_captions



def image_to_topk_texts(model, image_tensor, all_txt_embs, all_captions,
                        k=5, device="cuda"):
    """
    image_tensor: [3,224,224] image transformée
    all_txt_embs: [N, D]
    all_captions: liste de strings de longueur N
    """

    model.eval()

    with torch.no_grad():
        #  Embedding img
        img = image_tensor.unsqueeze(0).to(device)  #  [1,3,224,224]
        img_emb = model.vision(img)[0]              # [D]
        img_emb = F.normalize(img_emb, dim=-1)

        # Normalisation embeddings texte
        txt_embs = F.normalize(all_txt_embs.to(device), dim=-1)

        # Similarité image  tous les textes
        sims = txt_embs @ img_emb                   #  [N]

        
        topk_vals, topk_idx = sims.topk(k)
        topk_vals = topk_vals.cpu()


        topk_texts = [all_captions[i] for i in topk_idx.cpu().tolist()]

    return topk_texts, topk_vals

img_tensor = test_dataset.__getitem__(11)["image"]  # récupère juste l'image
img = img_tensor.permute(1, 2, 0).cpu().numpy()
plt.imshow(img)
plt.axis("off")
plt.show()
all_txt_embs, all_captions = compute_text_embeddings(model_clip, val_loader, device)
topk_texts, topk_vals = image_to_topk_texts(model_clip, img_tensor, all_txt_embs, all_captions)
for txt_result, score in zip(topk_texts, topk_vals):
    print(txt_result, score)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.4831376].
# The sandy brown dog was running around in circles, its tail wagging excitedly as it chased after the soccer ball on the sun-kissed lawn. The ball bounced and rolled across the grass, its synthetic leather surface glinting in the bright sunlight. In the background, a few trees swayed gently in the breeze, their leaves rustling softly as the dog continued to playfully pursue its beloved ball. tensor(0.3026)
# A sleek black agility dog, its fur glistening with sweat, navigates a challenging obstacle course with ease, expertly weaving in and out of towering poles set up by its enthusiastic owner. The dog's paws barely touch the ground as it springs from one pole to the next, its tail wagging triumphantly in the air. The scene is bathed in the warm glow of late afternoon sunlight, casting long shadows across the grassy terrain. tensor(0.2303)
# The man in the beret pedaled his bicycle down the cobblestone street, weaving past pedestrians who stopped to glance at the colorful market stalls set up along the way. A few children played tag on the sidewalk, their laughter carrying through the crisp morning air as they chased each other towards the city square. The sun cast a warm glow over the scene, illuminating the vibrant flowers arranged in a nearby vendor's cart. tensor(0.2084)
# A group of bicyclists in a race, their sleek road bikes speeding down the winding course as they compete for the top finish. The sun beats down on the pavement, casting long shadows behind the riders as they pedal furiously through the turn. In the distance, a crowd cheers them on, their voices carrying above the sound of wheels on asphalt. tensor(0.1158)
# A serene riverbank scene unfolds, with sunlight filtering through the trees above. A man stands waist-deep in the calm waters, his fly fishing rod cast out into the gentle current as he waits for a bite. The soft ripples on the surface of the river create a soothing melody that echoes through the peaceful surroundings. tensor(0.1112)
